# %%
from google.colab import userdata
key = userdata.get('GEMINI_API_KEY')

# %%
import google.generativeai as genai

genai.configure(api_key=key)
# Out:
# /usr/local/lib/python3.12/dist-packages/google/colab/_import_hooks/_hook_injector.py:55: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   loader.exec_module(module)

# %%
model = genai.GenerativeModel("gemini-2.5-flash")
#response = model.generate_content("Hi My name is Anuradha. hat is your name")
response = model.generate_content("Hi mera naam omkar hai. aap ka naam kya hai")
print(response.text)
# Out:
# नमस्कार ओमकार! मेरा कोई नाम नहीं है। मैं एक बड़ा भाषा मॉडल हूँ, जिसे Google ने प्रशिक्षित किया है।

# %%
# genai.configure(api_key= "AIzaSyAoHiol2tjpz3HC3dzmQ5V1aOd8JrKio28")
model = genai.GenerativeModel("gemini-2.5-flash")

for attempt in range(5):
    try:
        response = model.generate_content(
            "Hi mera naam Omkar hai. Aap ka naam kya hai?"
        )
        print(response.text)
        break
    except TooManyRequests:
        wait_time = 2 ** attempt
        print(f"Rate limit hit. Retrying in {wait_time}s...")
        time.sleep(wait_time)
# Out:
# नमस्ते ओमकार! मेरा नाम असिस्टेंट है। मुझे आपसे मिलकर खुशी हुई।

# %%
import PIL.Image

sample_file = PIL.Image.open('1.png')

# %%
# Choose a Gemini model.
model = genai.GenerativeModel(model_name="gemini-2.5-flash")

prompt = "What can you tell me about this picture?"
response = model.generate_content([prompt, sample_file])

display(response.text)
# Out:
# 'This image is a promotional graphic or poster for an entrepreneurial event called **VISHWAPRENEUR\'25**.\n\nHere\'s a breakdown of what the picture tells us:\n\n1.  **Event Name and Year:** The prominent text in the center reads "VISHWAPRENEUR\'25," indicating the name of the event and that it is scheduled for the year 2025.\n\n2.  **Tagline:** Below the event name, the tagline "ASCENSION TO GREATNESS" is displayed, conveying a theme of growth, ambition, and success.\n\n3.  **Organizer:**\n    *   At the top center, it states "ENTREPRENEURSHIP DEVELOPMENT CELL, VIIT\'S." This identifies the organizing body as the Entrepreneurship Development Cell (EDC) of VIIT (likely Vishwakarma Institute of Information Technology, given the "Vishwapraneur" name).\n    *   The top right corner features a logo with "EDC" clearly visible, along with two hands shaking, further emphasizing the entrepreneurial and collaborative nature of the event.\n\n4.  **Event Branding/Edition:** In the top left corn
# ...

# %%
result = genai.embed_content(
    model="models/text-embedding-004",
    content="What is the meaning of life?",
    task_type="retrieval_document",
    title="Embedding of single string")

# 1 input > 1 vector output
print(str(result['embedding'])[:50], '... TRIMMED]')
# Out:
# [-0.02854543, 0.044588115, -0.034197364, -0.004266 ... TRIMMED]
